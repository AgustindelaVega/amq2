# %%
import awswrangler as wr

import mlflow

# Para que funciones, todos nuestros scripts debemos exportar las siguientes variables de entorno
# %env AWS_ACCESS_KEY_ID=minio   
# %env AWS_SECRET_ACCESS_KEY=minio123 
# %env MLFLOW_S3_ENDPOINT_URL=http://localhost:9000
# %env AWS_ENDPOINT_URL_S3=http://localhost:9000
# Out:
# env: AWS_ACCESS_KEY_ID=minio
# env: AWS_SECRET_ACCESS_KEY=minio123
# env: MLFLOW_S3_ENDPOINT_URL=http://localhost:9000
# env: AWS_ENDPOINT_URL_S3=http://localhost:9000

# %% [markdown]
# # Búsqueda de mejor modelo e hiperparámetros
#
# Dado nuestro dataset de Heart Disease, el cual ya pasó por el proceso de ETL y se encuentra en nuestro S3 bucket, vamos a realizar una búsqueda de cual seria el mejor modelo y que hiperparametros usar.
#
# La búsqueda de hiperparametros la haremos usando Optuna y el tracking será realizado mediante MLFlow.
#
# OBS: Para la confección de esta notebook, nos basamos en el tutorial de [MLFlow](https://mlflow.org/docs/latest/traditional-ml/hyperparameter-tuning-with-child-runs/notebooks/index.html).

# %%
mlflow_server = "http://localhost:5001"

mlflow.set_tracking_uri(mlflow_server)

# %%
# Cargamos los datos para realizar nuestro estudio.
# OBS, no vamos a cargar los datos de testing, nada de Data leakage por aquí
X_train =  wr.s3.read_csv("s3://data/final/train/spotify_X_train.csv")
y_train =  wr.s3.read_csv("s3://data/final/train/spotify_y_train.csv")

X_test =  wr.s3.read_csv("s3://data/final/test/spotify_X_test.csv")
y_test =  wr.s3.read_csv("s3://data/final/test/spotify_y_test.csv")

# %% [markdown]
# ## Investigamos la correlación de features con la variable objetivo
#
# Antes de profundizar en el proceso de construcción de modelo, es esencial comprender las relaciones entre nuestras features  y la variable objetivo. Por lo que vamos a realizar un gráfico que indica el coeficiente de correlación de cada feature en relación con la variable objetivo. Esto nos sirve para:
#
# - Evitar data leakage: Debemos asegurarnos de que ninguna característica se correlacione perfectamente con el objetivo (un coeficiente de correlación de aproximadamente 1.0). Si existe tal correlación, es una señal de que nuestro conjunto de datos podría estar "filtrando" información sobre el objetivo.
#
# - Garantizar relaciones significativas: Idealmente, nuestras características deberían tener algún grado de correlación con el objetivo. Inclusive si estamos trabajando con un problema de clasificación, aunque los resultados no son tan importantes como en un caso de regresión.
#
# - Auditoría y trazabilidad: Loggear esta visualización de correlación con nuestra ejecución principal de MLflow garantiza la trazabilidad. Proporciona una instantánea de las características de los datos en el momento del entrenamiento del modelo, lo cual es invaluable para propósitos de auditoría y replicabilidad.

# %%
from plots import plot_correlation_with_target, plot_information_gain_with_target

# %%
# Dado que estamos usando como tracking a MLFlow, mostrar los gráficos aquí no tiene sentido.
correlation_plot = plot_correlation_with_target(X_train, y_train, "label")
information_gain_plot = plot_information_gain_with_target(X_train, y_train, "label")

# %% [markdown]
# ## Arrancamos a experimentar

# %%
import datetime
import optuna

from mlflow.models import infer_signature
from mlflow_aux import get_or_create_experiment

from optuna_aux import champion_callback, objective

from sklearn.svm import SVC 
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score

from lightgbm import LGBMClassifier

# Optuna es un poco verboso, dejamos que solo nos muestre logs de errores
optuna.logging.set_verbosity(optuna.logging.ERROR)

# %% [markdown]
# Antes de poder realizar experimentos, vamos a crear el experimento en MLFLow, pero para evitar desorden, vamos a usar una función que se fije primero si el experimento existe, si esto es así, devuelve su ID.
#
# Además creamos el nombre del run padre con el que vamos a ir registrando las ejecuciones.

# %%
# Creemos el experimento
experiment_id = get_or_create_experiment("Spotify Playlist")

run_name_parent = "best_hyperparam_"  + datetime.datetime.today().strftime('%Y/%m/%d-%H:%M:%S"')

# %% [markdown]
# Ya con todo seteado, vamos a ejecutar la optimización usando Optuna, el cual realiza una búsqueda Bayesiana, la cual es más eficiente que una búsqueda de grilla tradicional. La desventaja es que es más difícil de paralelizar.

# %%
with mlflow.start_run(experiment_id=experiment_id, run_name=run_name_parent, nested=True):
    # Inicializamos el estudio de Optuna
    study = optuna.create_study(direction="maximize")

    # Ejecutamos los trials de optimización de hiperparametros. Cada uno de estos trials se ejecuta con un run separado, pero 
    # está anidado al run padre.
    # Notar la adición del `champion_callback` para controlar qué mensajes mostramos
    # Para entender mejor esto ver la documentación de objective y champion_callback en optuna_aux
    study.optimize(lambda trial: objective(trial, X_train, y_train, experiment_id), n_trials=250, callbacks=[champion_callback])

    # Una vez que terminamos la búsqueda, guardamos los mejores parámetros en el run padre.
    mlflow.log_params(study.best_params)
    mlflow.log_metric("best_train_f1", study.best_value)

    mlflow.set_tags(
        tags={
            "project": "Spotify Playlist",
            "optimizer_engine": "optuna",
            "model_family": "sklearn",
            "feature_set_version": 1,
        }
    )

    # Una vez que terminamos la búsqueda, nos quedamos con el mejor modelo y lo entrenamos
    if study.best_params["classifier"] == "SVC_linear":
        model = SVC(C=study.best_params["svc_c"], kernel='linear', gamma='scale')
    elif study.best_params["classifier"] == "SVC_poly":
        model = SVC(C=study.best_params["svc_c"], kernel='poly', 
                    gamma='scale', degree=study.best_params["svc_poly_degree"])
    elif study.best_params["classifier"] == "SVC_rbf":
        model = SVC(C=study.best_params["svc_c"], kernel='rbf', gamma='scale')
    elif study.best_params["classifier"] == "DecisionTreeClassifier":
        model = DecisionTreeClassifier(max_depth=study.best_params["tree_max_depth"])
    elif study.best_params["classifier"] == "RandomForest":
        model = RandomForestClassifier(max_depth=study.best_params["rf_max_depth"], 
                                       n_estimators=study.best_params["rf_n_estimators"])
    else:
        model = LGBMClassifier(
                n_estimators=study.best_params["lgbm_n_estimators"],
                max_depth=study.best_params["lgbm_max_depth"],
                num_leaves=study.best_params["lgbm_num_leaves"]
            )

    model = model.fit(X_train, y_train.to_numpy().ravel())

    # Y testeamos el modelo y logueamos el resultado
    y_pred = model.predict(X_test)
    f1_score = f1_score(y_test.to_numpy().ravel(), y_pred)
    mlflow.log_metric("test_f1", f1_score)

    # Logueamos los artefactos de las gráficas de correlación y de information_gain
    mlflow.log_figure(figure=correlation_plot, artifact_file="correlation_plot.png")
    mlflow.log_figure(figure=information_gain_plot, artifact_file="information_gain_plot.png")

    # Guardamos el artefacto del modelo
    artifact_path = "model"

    signature = infer_signature(X_train, model.predict(X_train))

    mlflow.sklearn.log_model(
        sk_model=model,
        artifact_path=artifact_path,
        signature=signature,
        serialization_format='cloudpickle',
        registered_model_name="spotify_playlist_model_dev",
        metadata={"model_data_version": 1}
    )

    # Obtenemos la ubicación del modelo guardado en MLFlow
    model_uri = mlflow.get_artifact_uri(artifact_path)
# Out:
# 🏃 View run Trial: 0 at: http://localhost:5001/#/experiments/1/runs/9f59e15f7f684d22816bc7424bff0bb7
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# Initial trial 0 achieved value: 0.8143985586269025
# 🏃 View run Trial: 1 at: http://localhost:5001/#/experiments/1/runs/0d787c5fda7e4689a4ed89d299cf8120
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# Trial 1 achieved value: 0.8312261447472714 with  2.0244% improvement
# 🏃 View run Trial: 2 at: http://localhost:5001/#/experiments/1/runs/0b602584627945bda382d16f111bafc6
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 3 at: http://localhost:5001/#/experiments/1/runs/4e8961dfbb4242f29381e7d19c3c7936
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# Trial 3 achieved value: 0.8348040722710465 with  0.4286% improvement
# 🏃 View run Trial: 4 at: http://localhost:5001/#/experiments/1/runs/17053ffd451c4a0fb402f4b5781e4434
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 5 at: http://localhost:5001/#/experiments/1/runs/34b95cdfc95c4b8e8edfe2eb973eb653
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 6 at: http://localhost:5001/#/experiments/1/runs/5a09835bd5274f79af41cd053eabaea9
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 7 at: http://localhost:5001/#/experiments/1/runs/bd977b5b25e546bdbc7e2bc8b6bb6629
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 8 at: http://localhost:5001/#/experiments/1/runs/6c9e1de5145d44f881f9c8f49705277c
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# Trial 8 achieved value: 0.8475905583258087 with  1.5086% improvement
# 🏃 View run Trial: 9 at: http://localhost:5001/#/experiments/1/runs/209074dffebb47469b8fa1fdbe851715
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 10 at: http://localhost:5001/#/experiments/1/runs/1813210adb2a42d2b2e59329f762222a
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 11 at: http://localhost:5001/#/experiments/1/runs/35217ff8b9f243c49c714047f12552dc
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 12 at: http://localhost:5001/#/experiments/1/runs/51ba0f934352428fbaf499c4661bbc45
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 13 at: http://localhost:5001/#/experiments/1/runs/8f2ea9f5f2e94ea9973c2ae6b54edf2e
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 14 at: http://localhost:5001/#/experiments/1/runs/acc3b193ad3c44a9a23dc6e997cd5008
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 15 at: http://localhost:5001/#/experiments/1/runs/ed62e283fb3247c4aa0f699b45dbe446
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# Trial 15 achieved value: 0.8496419809204294 with  0.2414% improvement
# 🏃 View run Trial: 16 at: http://localhost:5001/#/experiments/1/runs/00d999b9db704958a1dea6a0133f1b36
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 17 at: http://localhost:5001/#/experiments/1/runs/2f7882987605482b8a1ca3cb41c8430f
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 18 at: http://localhost:5001/#/experiments/1/runs/f81a1a9ec31d4ce8a979365db850426b
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 19 at: http://localhost:5001/#/experiments/1/runs/9711e8893a8f44e6a3dcb9e9b2bd44d3
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 20 at: http://localhost:5001/#/experiments/1/runs/28970452bbeb4d58a771d69d921d0724
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 21 at: http://localhost:5001/#/experiments/1/runs/eb03ca79df4348699b28f5ff486b04c1
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 22 at: http://localhost:5001/#/experiments/1/runs/08bae916a4cc4e3091032d82e356d0d8
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 23 at: http://localhost:5001/#/experiments/1/runs/e285935f407e4732b898168f48a9f213
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 24 at: http://localhost:5001/#/experiments/1/runs/08e55270d53c4ef2be335dc72e5fffcf
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 25 at: http://localhost:5001/#/experiments/1/runs/aece0073654543d398ff6cf9127f5b48
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 26 at: http://localhost:5001/#/experiments/1/runs/b649e0ec0bd64b9c9a29c57a299b102c
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 27 at: http://localhost:5001/#/experiments/1/runs/260f3d910e2b4d859eb39f9709584f08
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 28 at: http://localhost:5001/#/experiments/1/runs/5f7e023a848f43f6a1962283e7b63a3e
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 29 at: http://localhost:5001/#/experiments/1/runs/1f1ced9555654601b16fd61fa0920546
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 30 at: http://localhost:5001/#/experiments/1/runs/ba2d4469dd7f4acbbda45d9bf10833ba
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 31 at: http://localhost:5001/#/experiments/1/runs/3907330e1bbc43aa8a905274f65a6208
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 32 at: http://localhost:5001/#/experiments/1/runs/518e1dd781fe4f358c3a127826b619c6
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 33 at: http://localhost:5001/#/experiments/1/runs/2a3129908e5e41c5b662837a1bcc11ca
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 34 at: http://localhost:5001/#/experiments/1/runs/13237512d13d4937b8cca82347fc4559
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 35 at: http://localhost:5001/#/experiments/1/runs/8f8780e6e898469fb9404a335befa20d
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 36 at: http://localhost:5001/#/experiments/1/runs/9d22d7cc5ab94bd2b328c9fc6a5f0ee9
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 37 at: http://localhost:5001/#/experiments/1/runs/fe9ab09799d94f0995c1c70f3b5389f0
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 38 at: http://localhost:5001/#/experiments/1/runs/307026ef34f44d5f9b42ce5b0d8d3974
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 39 at: http://localhost:5001/#/experiments/1/runs/dcdf058785bc4c58bcb1bc618d7aa520
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 40 at: http://localhost:5001/#/experiments/1/runs/7ccfbc64a3f244f8aa4d8600ca841eea
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 41 at: http://localhost:5001/#/experiments/1/runs/4cd695dfb68147568a1fcd8e9df17bf0
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 42 at: http://localhost:5001/#/experiments/1/runs/8af4dcd1b3ab43e39532c5ec8b4534d3
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 43 at: http://localhost:5001/#/experiments/1/runs/dad725a131534645992121bc22d2092e
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 44 at: http://localhost:5001/#/experiments/1/runs/d4834a473c9b43b4862b0a9d3c7caa1d
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 45 at: http://localhost:5001/#/experiments/1/runs/f538dfa4330548a39fa701171930e2d7
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 46 at: http://localhost:5001/#/experiments/1/runs/de410dff14ac4b23bc7afe2f92ae8140
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 47 at: http://localhost:5001/#/experiments/1/runs/dbe41c6de2554365afa14b63d73d55cc
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 48 at: http://localhost:5001/#/experiments/1/runs/783beeb26ed64f00bde0bcfda6c58a18
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 49 at: http://localhost:5001/#/experiments/1/runs/218b92ab0f2a4c7c9624e7c79ae83478
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 50 at: http://localhost:5001/#/experiments/1/runs/e4b64145f0e243d8b3a261509c0a1a10
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 51 at: http://localhost:5001/#/experiments/1/runs/d821b34c2e6f4ca197b0654e950d141c
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 52 at: http://localhost:5001/#/experiments/1/runs/f03a2a620f2141088a11d7313cc35011
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 53 at: http://localhost:5001/#/experiments/1/runs/ccbc4b20a95d41fbaacd854d96313d4f
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 54 at: http://localhost:5001/#/experiments/1/runs/c25c8fadbf214dcc8bf097b8f0089e68
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 55 at: http://localhost:5001/#/experiments/1/runs/80fa46be318e4d4eaf528e0551d35a6e
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 56 at: http://localhost:5001/#/experiments/1/runs/b6616568db204f78af124cd29acbc606
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 57 at: http://localhost:5001/#/experiments/1/runs/110bdfd1df054cf3bc4c6e22f08ffa52
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 58 at: http://localhost:5001/#/experiments/1/runs/c5eb38741e6d4727a3d96008b0c8fd07
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 59 at: http://localhost:5001/#/experiments/1/runs/98f96eaf3b0d4ef9b1429e62202d631a
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 60 at: http://localhost:5001/#/experiments/1/runs/8343d9f41e0149a9b38e4d53125e39aa
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 61 at: http://localhost:5001/#/experiments/1/runs/f85e353e76c94406b046201df747dc8a
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 62 at: http://localhost:5001/#/experiments/1/runs/d0774aab3a6e43159f4d27ba700a8af3
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 63 at: http://localhost:5001/#/experiments/1/runs/0e7c13ad244f406f8aefe38e7c307c63
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 64 at: http://localhost:5001/#/experiments/1/runs/31ec4de134d44ac280b565a4c7cccec7
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 65 at: http://localhost:5001/#/experiments/1/runs/065e4df951a24736a1fbced0103d96a6
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 66 at: http://localhost:5001/#/experiments/1/runs/aa0ce03c456441949db01f948bdddd35
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 67 at: http://localhost:5001/#/experiments/1/runs/8132e8144a0249d2a3b08e85a6223183
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 68 at: http://localhost:5001/#/experiments/1/runs/0e7dff59c9ea429ea748f2258f8a9be1
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 69 at: http://localhost:5001/#/experiments/1/runs/19db4c8a77a44458aaa19962333e6047
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 70 at: http://localhost:5001/#/experiments/1/runs/baf9990079cf4484a286ceeebcb396d2
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 71 at: http://localhost:5001/#/experiments/1/runs/f61177942927485eb5a6e83f0066f1d5
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 72 at: http://localhost:5001/#/experiments/1/runs/d96a0a83ea9644ba9f298cd7fb246f42
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 73 at: http://localhost:5001/#/experiments/1/runs/6a7ede82b48342ccae45b5e203bdf50c
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 74 at: http://localhost:5001/#/experiments/1/runs/01ced9de2cba40268bd69a490a2ff12b
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 75 at: http://localhost:5001/#/experiments/1/runs/d607e39d0f2f4591b7b21f006d532221
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 76 at: http://localhost:5001/#/experiments/1/runs/d401e9ea4e744e3a8b75aee0c79d9703
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 77 at: http://localhost:5001/#/experiments/1/runs/0ec7e4266888450ea4e3c2946bf42041
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 78 at: http://localhost:5001/#/experiments/1/runs/621aee31858747a8bd40bab70eaba65c
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 79 at: http://localhost:5001/#/experiments/1/runs/3356bd81fc3f43029c4a037e3bd66a86
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 80 at: http://localhost:5001/#/experiments/1/runs/1ba9315f95cf41159e0a4f41729dcb65
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 81 at: http://localhost:5001/#/experiments/1/runs/e1926ea8e81c48ff86d575a18b3890b8
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 82 at: http://localhost:5001/#/experiments/1/runs/cd3a0187e0f54644b8f32981dd285c44
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 83 at: http://localhost:5001/#/experiments/1/runs/df21a2baeaa44e13ad187a687e6fbd83
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 84 at: http://localhost:5001/#/experiments/1/runs/a1858c4d68c44dedb022209afe622c07
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 85 at: http://localhost:5001/#/experiments/1/runs/a4fda22230f5403eaf995fd33ec69959
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 86 at: http://localhost:5001/#/experiments/1/runs/449a7774508343588772afe75974156f
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 87 at: http://localhost:5001/#/experiments/1/runs/06fc5620eaa542b3925f954364eac021
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 88 at: http://localhost:5001/#/experiments/1/runs/9cfa07297eea476187e3bbdd60a086a0
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 89 at: http://localhost:5001/#/experiments/1/runs/8e7fe1ffcebe4f66b8e3a332ce1550f9
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 90 at: http://localhost:5001/#/experiments/1/runs/7cf3d7a2aa17462eb4347412932a14d8
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 91 at: http://localhost:5001/#/experiments/1/runs/a412ac2860e14b82a2c3908324b19700
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 92 at: http://localhost:5001/#/experiments/1/runs/d03473ce853040e1a266812fd7c76b51
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# Trial 92 achieved value: 0.8502800750321271 with  0.0750% improvement
# 🏃 View run Trial: 93 at: http://localhost:5001/#/experiments/1/runs/14ca913612154534807e0c4039a06ded
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 94 at: http://localhost:5001/#/experiments/1/runs/7efd805b320f4cfd9711adf6f715c886
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 95 at: http://localhost:5001/#/experiments/1/runs/e3dce3b0bbbb4f7dbd591611fa2535fc
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 96 at: http://localhost:5001/#/experiments/1/runs/1bf5cac1e39041b4a2d2d12115dc9386
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 97 at: http://localhost:5001/#/experiments/1/runs/650e4baac13347db9ef662b3b6e4cf35
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 98 at: http://localhost:5001/#/experiments/1/runs/c09dbe09165640bdb644aafef65ef216
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 99 at: http://localhost:5001/#/experiments/1/runs/2bcb460f99414ee5ae646ca1136ff2c7
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 100 at: http://localhost:5001/#/experiments/1/runs/e4199c6729444b32b67ad010d7c4293f
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 101 at: http://localhost:5001/#/experiments/1/runs/0ca7f23586a54538890fe07399d4f1bb
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 102 at: http://localhost:5001/#/experiments/1/runs/e5a39d77a7504ef6be50e9f15f373fc9
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 103 at: http://localhost:5001/#/experiments/1/runs/6ef278d813c64a97b6a0bf68f2513489
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 104 at: http://localhost:5001/#/experiments/1/runs/152b89e2bdd24fb5b87f23f49d964434
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 105 at: http://localhost:5001/#/experiments/1/runs/1140753a4b584daf8d032ddad9a1a350
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 106 at: http://localhost:5001/#/experiments/1/runs/6265a4116bb949b0821dabb43dfe1ac0
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 107 at: http://localhost:5001/#/experiments/1/runs/491ad99d9c794722ac2265d7083c6891
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 108 at: http://localhost:5001/#/experiments/1/runs/7cc0553a391f4efe96f74f4389402eb1
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 109 at: http://localhost:5001/#/experiments/1/runs/5065d726b8f641e3ae8f58a7b020cca2
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 110 at: http://localhost:5001/#/experiments/1/runs/0b172c723c6c4ba8940f47dca3e1cb92
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 111 at: http://localhost:5001/#/experiments/1/runs/55f1c9e55a0f4ce0b0b3a1d1caae4dd6
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# Trial 111 achieved value: 0.8506351256268369 with  0.0417% improvement
# 🏃 View run Trial: 112 at: http://localhost:5001/#/experiments/1/runs/1314a11c729c45a0ba619370d32d3e07
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 113 at: http://localhost:5001/#/experiments/1/runs/fa5ed70025df4c33abac3d30bf8f0b4d
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 114 at: http://localhost:5001/#/experiments/1/runs/740dab816b3742719c19aad7a7df7601
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 115 at: http://localhost:5001/#/experiments/1/runs/1fb3d858e0e6499f8620ce2626116e35
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 116 at: http://localhost:5001/#/experiments/1/runs/59777f3a30064d1da96cb8776c8425da
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 117 at: http://localhost:5001/#/experiments/1/runs/e29d20dd41744133a5ab03979635caa0
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 118 at: http://localhost:5001/#/experiments/1/runs/ad43db9c69424175b9ce956b7c5dda3f
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 119 at: http://localhost:5001/#/experiments/1/runs/99210ccf6f9746369fe6cb80a7aec393
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 120 at: http://localhost:5001/#/experiments/1/runs/735667ddb08d4288a64f203b73ece583
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 121 at: http://localhost:5001/#/experiments/1/runs/45593aa788b245b1a0a7e7502d9d0700
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 122 at: http://localhost:5001/#/experiments/1/runs/5dd5fbd4c669491db082b4d33ecc89a9
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 123 at: http://localhost:5001/#/experiments/1/runs/7d505571cef344b5b9f23f40b205e65d
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 124 at: http://localhost:5001/#/experiments/1/runs/d4c20c13e7aa442998d20aa9c89e299f
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 125 at: http://localhost:5001/#/experiments/1/runs/a9db206370954247aefb8157f89f80e9
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 126 at: http://localhost:5001/#/experiments/1/runs/2ec5420e11f84ceb830e652910729128
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 127 at: http://localhost:5001/#/experiments/1/runs/eb56f5e4075344f8b5d9da5474c32143
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 128 at: http://localhost:5001/#/experiments/1/runs/eeca6e6a0d384e22a052e46d01618021
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 129 at: http://localhost:5001/#/experiments/1/runs/d37a30747772433b8211679a5b44ab35
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 130 at: http://localhost:5001/#/experiments/1/runs/ba15e1d75e564ffb85d4b63653057cf7
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 131 at: http://localhost:5001/#/experiments/1/runs/24b5fa24ab8745a9b05be9bf01a68b9a
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 132 at: http://localhost:5001/#/experiments/1/runs/3b7cdbd13f234648840d25c125c22ce8
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 133 at: http://localhost:5001/#/experiments/1/runs/75fc3ac25ef04d71881da9b7c820c65f
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 134 at: http://localhost:5001/#/experiments/1/runs/85e86ecc60bc4f1cadc334e77ed408fc
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 135 at: http://localhost:5001/#/experiments/1/runs/b805f54db3724698abef9547526a1c5b
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 136 at: http://localhost:5001/#/experiments/1/runs/461cc3f0c38443a9b82987df9864180a
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 137 at: http://localhost:5001/#/experiments/1/runs/defe0ab710c74c618781c4c7a60117db
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 138 at: http://localhost:5001/#/experiments/1/runs/57013e9c66d94ddbb0769216526bc45b
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 139 at: http://localhost:5001/#/experiments/1/runs/003102a2b6c945f2a7ed1c1acc8ccc8d
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 140 at: http://localhost:5001/#/experiments/1/runs/49fd83eea67d4188b035070926329d23
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 141 at: http://localhost:5001/#/experiments/1/runs/1bddf7119c2b4b86858b69dbcfbb9c4a
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 142 at: http://localhost:5001/#/experiments/1/runs/b083be8abc5d469ebe5fef80206c8791
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 143 at: http://localhost:5001/#/experiments/1/runs/0efe02af75fd43e6bbf911d6c1abd32c
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 144 at: http://localhost:5001/#/experiments/1/runs/4ebfe8ea11604bd0bdd3416e9d26ff39
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 145 at: http://localhost:5001/#/experiments/1/runs/a9bd952c2f5c42ee97383fee5ea1a9f7
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 146 at: http://localhost:5001/#/experiments/1/runs/0af31b0122024cbcb3db96f2bf099fcc
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 147 at: http://localhost:5001/#/experiments/1/runs/89a01494fc204a56a869ad0dce5e107d
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 148 at: http://localhost:5001/#/experiments/1/runs/d621500ab8534b93960453b83c6985e5
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 149 at: http://localhost:5001/#/experiments/1/runs/c49c9d689d5a4a2e955d30d23c469729
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 150 at: http://localhost:5001/#/experiments/1/runs/03beef9fb9c3485e94693c6c169d232b
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 151 at: http://localhost:5001/#/experiments/1/runs/d7628bf2b59e4b839bcde734547387de
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 152 at: http://localhost:5001/#/experiments/1/runs/9020b5caa2594f1cbf923b7f0bb5c5c0
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 153 at: http://localhost:5001/#/experiments/1/runs/686f4b0cac2c4e7cb514076d05f4307a
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 154 at: http://localhost:5001/#/experiments/1/runs/cd40971769e8403aabf7e0751f11db56
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 155 at: http://localhost:5001/#/experiments/1/runs/db659f4473334fd0b2ba7429e85625b1
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 156 at: http://localhost:5001/#/experiments/1/runs/3d5e32aed06d49bda6de8e9f958657f7
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 157 at: http://localhost:5001/#/experiments/1/runs/9c01c0be395d466d96f2893265f3c805
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 158 at: http://localhost:5001/#/experiments/1/runs/e8585d96e09f4a5aae6dc6fd06140405
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 159 at: http://localhost:5001/#/experiments/1/runs/c12634c16bfe4430ae8981c4eec9d406
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 160 at: http://localhost:5001/#/experiments/1/runs/63db16a4731a4b0aa3045429139d60a2
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 161 at: http://localhost:5001/#/experiments/1/runs/5968c1cb6a814116ab304f8770d5169d
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 162 at: http://localhost:5001/#/experiments/1/runs/9c654fbaa8d24714bcabcbead607308f
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 163 at: http://localhost:5001/#/experiments/1/runs/fa76b933fe394bf08504fc0f89e1eb86
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 164 at: http://localhost:5001/#/experiments/1/runs/b9819a281d174003852326128089a79c
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 165 at: http://localhost:5001/#/experiments/1/runs/55b3be19cf6f4dd6a14dfb36c0c4675d
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 166 at: http://localhost:5001/#/experiments/1/runs/ece48aa14c66450b80435b6ebcce4e74
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 167 at: http://localhost:5001/#/experiments/1/runs/bd1e54bb316940b9b9156eec511415da
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 168 at: http://localhost:5001/#/experiments/1/runs/25cfcdf15e914a8a9155f95d040b4b43
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 169 at: http://localhost:5001/#/experiments/1/runs/834cc5874df14e18b01339ebab98ea27
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 170 at: http://localhost:5001/#/experiments/1/runs/009639d14e0c4e4aae84d3dd2d688207
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 171 at: http://localhost:5001/#/experiments/1/runs/df0e39f2f05b4554ac7ececc80543740
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 172 at: http://localhost:5001/#/experiments/1/runs/d07992898daa47b688e3f9867bbd71e3
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 173 at: http://localhost:5001/#/experiments/1/runs/90420f5d5d3d41679996ba57c7c8a3d4
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 174 at: http://localhost:5001/#/experiments/1/runs/3559cb6b70d64fc1a247debaeaad48c2
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 175 at: http://localhost:5001/#/experiments/1/runs/36d7155b9aef46c1848c90eda824128e
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 176 at: http://localhost:5001/#/experiments/1/runs/57f2d1fc4f1c464695ebf5a9d195510a
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 177 at: http://localhost:5001/#/experiments/1/runs/2a106b9b9e6e45108a573beb8871a46c
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 178 at: http://localhost:5001/#/experiments/1/runs/ef764c6f707c48b8a5aeb49f00f885c4
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 179 at: http://localhost:5001/#/experiments/1/runs/14ddbabf75ba4376be888e1a266388ca
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 180 at: http://localhost:5001/#/experiments/1/runs/8b480fbfba8841a688beaf957d7e0a7c
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 181 at: http://localhost:5001/#/experiments/1/runs/b29a4387aaaa4f1bb9ecfd4177adec6d
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 182 at: http://localhost:5001/#/experiments/1/runs/3b1c3dbfb30e4c4db52510692f628721
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 183 at: http://localhost:5001/#/experiments/1/runs/ff37053f832b41ce9cf6e3765d409f04
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 184 at: http://localhost:5001/#/experiments/1/runs/41bc3b7420c5445ba553ccdb92e3de91
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 185 at: http://localhost:5001/#/experiments/1/runs/c378f7edcae54c52a799904f9ccf8812
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 186 at: http://localhost:5001/#/experiments/1/runs/37ebff3ec6614c198822ffa46e2e5e90
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 187 at: http://localhost:5001/#/experiments/1/runs/2b68ec1b2f634cbfa37c3dace8c42e9b
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 188 at: http://localhost:5001/#/experiments/1/runs/dab4f377913f41cda5772c077d538e49
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 189 at: http://localhost:5001/#/experiments/1/runs/75a5a202aa944114b5d008b011f5e7c1
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 190 at: http://localhost:5001/#/experiments/1/runs/b6f979c3f12341dfb8edae135140431f
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 191 at: http://localhost:5001/#/experiments/1/runs/17022521ac2342bbb9a282b7a863756d
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 192 at: http://localhost:5001/#/experiments/1/runs/d30fca99140441cdae249c4b01771d29
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 193 at: http://localhost:5001/#/experiments/1/runs/be287d3dbd4b4dbaa4938d3f40f7f594
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 194 at: http://localhost:5001/#/experiments/1/runs/507c83f4d7ac467ba49629d9ac256e58
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 195 at: http://localhost:5001/#/experiments/1/runs/2d02bb9b22934626917a5e4ba07ccbc6
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 196 at: http://localhost:5001/#/experiments/1/runs/fa866d48faee440cb6dcea967a559b44
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 197 at: http://localhost:5001/#/experiments/1/runs/2413887d8a1f493aba66f77a7c19b6e9
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 198 at: http://localhost:5001/#/experiments/1/runs/2a64ab9aa8a44cfcaded6ffb90fda352
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 199 at: http://localhost:5001/#/experiments/1/runs/8ca5ecda243f48e184fb0b69b04a430a
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 200 at: http://localhost:5001/#/experiments/1/runs/8a0ce3929c204ef482ead520fa495c09
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 201 at: http://localhost:5001/#/experiments/1/runs/952137f8e1ac492d87a535e2a142bcb8
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 202 at: http://localhost:5001/#/experiments/1/runs/efe10ac6ba364943a956d61e92b2e37d
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 203 at: http://localhost:5001/#/experiments/1/runs/315d83179b0b4d25bb4df884bab3f8e4
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 204 at: http://localhost:5001/#/experiments/1/runs/6545fd07ab6541f3ac290727f7172dc8
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 205 at: http://localhost:5001/#/experiments/1/runs/df104d8143664fa19f8d982ce91d067a
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 206 at: http://localhost:5001/#/experiments/1/runs/1ea7c54c31574928bcc8eded4104b0f4
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 207 at: http://localhost:5001/#/experiments/1/runs/c407b3f0b2214a098f391622000230f2
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 208 at: http://localhost:5001/#/experiments/1/runs/cde8861df3174aa0afbc4f5c1c560ca8
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 209 at: http://localhost:5001/#/experiments/1/runs/d7828e944ce6478a98a602665db8f4d2
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 210 at: http://localhost:5001/#/experiments/1/runs/d3020e3834ba488bb279315ce1f43208
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 211 at: http://localhost:5001/#/experiments/1/runs/126251deb68545e593d500bef0babcaa
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 212 at: http://localhost:5001/#/experiments/1/runs/9a87443a4f7d4db9944fad8e8c6b345c
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 213 at: http://localhost:5001/#/experiments/1/runs/f44c7c0340c341df9989ab41ae3eeef9
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 214 at: http://localhost:5001/#/experiments/1/runs/dd939c91e9b5487887690da2c20da46b
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 215 at: http://localhost:5001/#/experiments/1/runs/87aeb7d5c026402cb4dee4ff0553ed7e
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 216 at: http://localhost:5001/#/experiments/1/runs/31ce4c6e23424800a3a0a53be811494f
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 217 at: http://localhost:5001/#/experiments/1/runs/00e558c44c074f7e82766021efe57ad9
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 218 at: http://localhost:5001/#/experiments/1/runs/17c863475a7246d4acb7bb287f11ef96
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 219 at: http://localhost:5001/#/experiments/1/runs/cc62ad6323704f9f8fcdae3187c4f8e1
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 220 at: http://localhost:5001/#/experiments/1/runs/13a1f217f98c47abb192381eec01d31e
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 221 at: http://localhost:5001/#/experiments/1/runs/96669cad48c343aa984433466daecd8e
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 222 at: http://localhost:5001/#/experiments/1/runs/a011c44c69044c3684ca1775c5271e6b
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 223 at: http://localhost:5001/#/experiments/1/runs/44953a2eb1034c5497b79bb7ddec746d
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 224 at: http://localhost:5001/#/experiments/1/runs/40d28d5f5f404ba2b54e131aa167fd69
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 225 at: http://localhost:5001/#/experiments/1/runs/cabf19d98056408d92c5775795f67af8
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 226 at: http://localhost:5001/#/experiments/1/runs/539fff7d0934428d81221437bd0bf0a6
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 227 at: http://localhost:5001/#/experiments/1/runs/cd879b4e0d4c49129ee23596744b5486
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 228 at: http://localhost:5001/#/experiments/1/runs/88f89970ba0e4645a456166bea155448
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 229 at: http://localhost:5001/#/experiments/1/runs/f91374fb0fc54351bf6600da394ca7bc
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 230 at: http://localhost:5001/#/experiments/1/runs/bcb354197a064518b9662cbee904b38c
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 231 at: http://localhost:5001/#/experiments/1/runs/313d77ad72104e2ab56d4234d93252cf
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 232 at: http://localhost:5001/#/experiments/1/runs/662d1b086808456da1c96381d749da91
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 233 at: http://localhost:5001/#/experiments/1/runs/75a1e2b61acc4b079699cd74db50eadf
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 234 at: http://localhost:5001/#/experiments/1/runs/9a568b159b8448e7afc75d3a71f1ddbc
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 235 at: http://localhost:5001/#/experiments/1/runs/3c6ad921e7e844758936033028b236e3
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 236 at: http://localhost:5001/#/experiments/1/runs/4519597a419a4a398be6e61a9e75949e
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 237 at: http://localhost:5001/#/experiments/1/runs/557cd94d118c42898c6b6cd874446c4f
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 238 at: http://localhost:5001/#/experiments/1/runs/3d4e0bf1bd6d4b71b4a198fc9d4349ca
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 239 at: http://localhost:5001/#/experiments/1/runs/833cbe42e4674ebf836eacb746c22253
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 240 at: http://localhost:5001/#/experiments/1/runs/9b51d3d55faf49b0a2898357abd6458c
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 241 at: http://localhost:5001/#/experiments/1/runs/d56ef2a245504eb5a928c2c3ddeabf96
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 242 at: http://localhost:5001/#/experiments/1/runs/408eed02c7af49eaa8b48d90e78053be
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 243 at: http://localhost:5001/#/experiments/1/runs/8f716187fab24f669c24d91c3e6fa7f4
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 244 at: http://localhost:5001/#/experiments/1/runs/a639ce65defe49b0bd7c6ec850b645c3
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 245 at: http://localhost:5001/#/experiments/1/runs/525d6915beaa4735815b8082b0ac8e49
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 246 at: http://localhost:5001/#/experiments/1/runs/0160441666f84d2295f2296ebf81309a
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 247 at: http://localhost:5001/#/experiments/1/runs/a9f889e597874f9eaae1563d271f2c4d
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 248 at: http://localhost:5001/#/experiments/1/runs/c10ecd57b6da441e978964cba574aaad
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 249 at: http://localhost:5001/#/experiments/1/runs/78c1eba4a725455cb0f2682b37943c5a
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# Successfully registered model 'spotify_playlist_model_dev'.
# 2024/12/12 19:23:38 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: spotify_playlist_model_dev, version 1
# 🏃 View run best_hyperparam_2024/12/12-19:23:03" at: http://localhost:5001/#/experiments/1/runs/e0481b4639d54b9e823cbb88e5b46c0e
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# Created version '1' of model 'spotify_playlist_model_dev'.

# %% [markdown]
# ## Registramos el modelo
#
# Realizamos el registro del modelo en MLflow. En este registro se pone el modelo productivo que luego se usará para servir en formato on-line.

# %%
from mlflow import MlflowClient

client = MlflowClient()
name = "spotify_playlist_model_prod"
desc = "This classifier detects if a person likes a given spotify song"

# Creamos el modelo productivo
client.create_registered_model(name=name, description=desc)

# Guardamos como tag los hiper-parametros en la version del modelo
tags = model.get_params()
tags["model"] = type(model).__name__
tags["f1-score"] = f1_score

# Guardamos la version del modelo
result = client.create_model_version(
    name=name,
    source=model_uri,
    run_id=model_uri.split("/")[-3],
    tags=tags
    
)

# Y creamos como la version con el alias de champion para poder levantarlo en nuestro
# proceso de servicio del modelo on-line.
client.set_registered_model_alias(name, "champion", result.version)
# Out:
# 2024/12/12 19:23:44 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: spotify_playlist_model_prod, version 1
